# %% [markdown]
# <a href="https://colab.research.google.com/github/Aubinrocky/Mall-customers/blob/main/MallCustomer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Aubinrocky/Mall-customers/main/Mall_Customers.csv')
del df["CustomerID"]

# %%
df.head()
# Out:
#     Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 4)

# %%
df.dtypes
# Out:
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
sns.pairplot(df)
